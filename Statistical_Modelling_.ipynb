# %% [markdown]
# <a href="https://colab.research.google.com/github/shristi13star/Statistical-Modelling-/blob/main/Statistical_Modelling_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #MEAN

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import builtins

# %%
ar=np.array([4,5,6,2,1,8,5,6,4,7])

# %%
np.sum(ar)/len(ar)
# Out:
# np.float64(4.8)

# %%
np.sort(ar)
# Out:
# array([1, 2, 4, 4, 5, 5, 6, 6, 7, 8])

# %%
dataset=pd.read_csv("/content/titanic (1).csv")

# %%
dataset.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
dataset['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
a=np.mean(dataset['Age'])

# %%
sns.histplot(x='Age',data=dataset,bins=[i for i in builtins.range(0,81,10)])
plt.plot([a for i in range(0,300)],[i for i in range(0,300)],c='blue')
plt.show()

# %% [markdown]
# #MEDIAN

# %% [markdown]
# Middle value of data

# %%
np.median(dataset['Age'])
# Out:
# np.float64(nan)

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
b=dataset['Age'].fillna(dataset['Age'].mean())

# %%
np.median(b)
# Out:
# np.float64(29.69911764705882)

# %%
c=np.median(dataset['Fare'])

# %%
sns.histplot(x='Age',data=dataset,bins=[i for i in builtins.range(0,81,10)])
plt.plot([a for i in range(0,300)],[i for i in range(0,300)],c='blue')
plt.plot([c for i in range(0,300)],[i for i in range(0,300)],c='red')
plt.show()

# %% [markdown]
# #MODE

# %% [markdown]
# Most frequency data.
# Mode is usually found in categorial data.

# %%
dataset['Fare'].mode()
type(dataset['Fare'].mode())
# Out:
# pandas.core.series.Series

# %%
d=dataset['Fare'].mode()[0]

# %%
dataset['Fare'].value_counts()
# Out:
# Fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 13.8583     1
# 50.4958     1
# 5.0000      1
# 9.8458      1
# 10.5167     1
# Name: count, Length: 248, dtype: int64

# %%
sns.histplot(x='Age',data=dataset,bins=[i for i in builtins.range(0,81,10)])
plt.plot([a for i in range(0,300)],[i for i in range(0,300)],c='blue',label="Mean")
plt.plot([c for i in range(0,300)],[i for i in range(0,300)],c='red',label="Median")
plt.plot([d for i in range(0,300)],[i for i in range(0,300)],c='green',label="Mode")
plt.legend()
plt.show()

# %% [markdown]
# #Measure of Variability

# %% [markdown]
# #Range

# %% [markdown]
# The range is the difference between the highest class and lowest class

# %%
e=dataset['Age'].max()

# %%
f=dataset['Age'].min()

# %%
e,f
# Out:
# (80.0, 0.42)

# %% [markdown]
# #Mean Absolute Deviation

# %% [markdown]
# It is the average distance between each data point and the mean.It give us an idea about the variability in a dataset.

# %%
sec_a=np.array([75,65,73,68,72,76])
sec_b=np.array([90,47,43,96,93,51])
no=np.array([1,2,3,4,5,6])

# %%
mean=np.mean(sec_b)

# %%
mean
# Out:
# np.float64(70.0)

# %%
plt.figure(figsize=(8,3))
plt.scatter(sec_a,no,label="Sec A")
plt.scatter(sec_b,no,color="red",label="Sec B")
plt.plot([70,70,70,70,70,70],no,c='blue',label="Mean")
plt.legend()
plt.show()

# %%
sum_A=np.sum(np.abs(sec_a-mean))/len(sec_a)

# %%
sum_A
# Out:
# np.float64(3.8333333333333335)

# %%
np.abs(sec_a-mean)
# Out:
# array([5., 5., 3., 2., 2., 6.])

# %% [markdown]
# #Varience // Standard Deviation

# %% [markdown]
# This defines the dispersion of a set of values.

# %%
np.std(sec_a),np.std(sec_b)
# Out:
# (np.float64(3.8622100754188224), np.float64(23.18045153428495))

# %%
np.var(sec_a),np.var(sec_b)
# Out:
# (np.float64(14.916666666666666), np.float64(537.3333333333334))

# %%
dataset['Age'].var()
# Out:
# 211.0191247463081

# %%
sns.histplot(x='Age',data=dataset)
plt.show()

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #Percentage v/s Percentile

# %% [markdown]
# The percentage is a comparison based on its base value while the percentile is a ranking-based comparison.

# %% [markdown]
# Interquartile Range is used to resolve outliers.
#
# * IQR=Q3-Q1
#
# * For minimum outlier =Q1-1.5* IQR

# %% [markdown]
# * For maximum outlier=Q3+1.5*IQR

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dataset["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
np.percentile(dataset['Age'],25),np.percentile(dataset['Age'],75)
# Out:
# (np.float64(nan), np.float64(nan))

# %%
sns.boxplot(x="Age",data=dataset)
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x="Fare",data=dataset)
# Out:
# <Axes: xlabel='Fare'>

# %% [markdown]
# #Measure of shape

# %% [markdown]
# * Skewness measures the asymmetry of the distribution.
# * 0 indicates a perfect symmetrical distribution
# * Positive indicates that the distribution is skewed to the right(that is tail is longer on the right). Mode<Median<Mean
# * While negative indicates a left skewed to the left(that is tail is longer on the left)Mean<Median<Mode
# ![image.png](data:image/png;base64,...)

# %%
sns.histplot(x="Age",data=dataset)
plt.plot()
# Out:
# []

# %%
dataset['Age'].mean(),dataset['Age'].median(),dataset['Age'].mode()[0]
# Out:
# (np.float64(29.69911764705882), 28.0, np.float64(24.0))

# %%
dataset["Age"].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
data=[1,1,1,2,2,3,3,4,4,4,5,5,5,6,6,7,7,8,8,9,9,10,10,11,11,11,12,12]

# %%
df=pd.DataFrame({"x":data})
df["x"].skew()
# Out:
# np.float64(0.07911986183929651)

# %%
sns.histplot(x="x",data=df)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Probability

# %% [markdown]
# Discrete Random Variable: countable number of distinct values
#
# Continuous Random Variable: Any value within a given range or interval

# %% [markdown]
# Probability Distribution
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The Probability Distribution Function is a function that gives the probabilities of occurrence of different possible outcomes for an experiment.
#
# It is of three types - PDF, PMF, and CDF.
#
# PDF represents continuous data, while PMF denotes discrete data.
#
# Normal DIstribution Function
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 60 percent part is 1st standard deviation
#
# 95 percent part is 2nd standard deviation
#
# 99 percent part is 3rd standard deviation

# %% [markdown]
# **Standard Normal Distribution**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Frequency distribution is mainly used to analyze the frequency of data.
#
# A probability distribution is used to predict the chances of data occurrence.

# %% [markdown]
# #Covarience and Coreleation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Positive covariance
#
# Negative Covariance
#
# Zero Covariance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Correlation is a range dependent thing

# %%
df1=pd.read_csv("/content/tips.csv")

# %%
df1.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
df1.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
cor=df1.select_dtypes(["float64","int64"]).corr()
cor
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
cov1=df1.select_dtypes(["float64","int64"]).cov()
cov1
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
plt.figure(figsize=(4,3))
sns.heatmap(cor,annot=True)
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.heatmap(cov1,annot=True)
plt.show()

# %% [markdown]
# #Central Limit Theorem

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pop_data=[np.random.randint(10,100) for i in range(10000)]
pop_table=pd.DataFrame({"Pop_data":pop_data})

# %%
np.mean(pop_data)
# Out:
# np.float64(54.3222)

# %%
plt.figure(figsize=(3,2))
sns.kdeplot(x="Pop_data",data=pop_table)
plt.show()

# %%
sam_mean=[]
for no_sample in range(50):
  sample_data=[]
  for data in range(500):
    sample_data.append(np.random.choice(pop_data))
  sam_mean.append(np.mean(sample_data))

# %%
sample_m=pd.DataFrame({"Sample_mean":sam_mean})

# %%
np.mean(sam_mean)
# Out:
# np.float64(54.32332)

# %%
plt.figure(figsize=(3,2))
sns.kdeplot(x="Sample_mean",data=sample_m)
plt.show()

# %% [markdown]
# CLT is used when the population data is not distributed normally

# %% [markdown]
# #Hypothesis Testing

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Types of Hypothesis Testing
#
# Z Test :work for average
#
# T Test: work for average
#
# Chi-Square Test: goodness and finding relation

# %% [markdown]
# Step of Hypothesis
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# State null(HO) and alternative (H1) Hypothesis
#
# HO must contain equality. H1 always coontains differnce (>,<)

# %% [markdown]
# Choose level of significance
#
# Denoted by alpha. It is a fixed probability of wrongly rejecting a True Null Hypothesis

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Find Statistical Test

# %% [markdown]
# #Hypothesis Testing (Z Test)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import scipy.stats as st
import numpy as np
st.norm.ppf(0.95)
# Out:
# np.float64(1.6448536269514722)

# %%
s_x=90
p_u=82
std_p=20
n=81
ap=0.05

# %%
z_cal=(s_x-p_u)/(std_p/np.sqrt(n))
z_cal
# Out:
# np.float64(3.5999999999999996)

# %%
z_table=st.norm.ppf(1-ap)
z_table
# Out:
# np.float64(1.6448536269514722)

# %%
if (z_table)<(z_cal):
  print("Null hypothesis is rejected")
else:
  print("Null hypothesis is accepted")
# Out:
# Null hypothesis is rejected

# %%
old=np.array([45.2,42.8,38.9,43.5,41.0,44.6,40.5,42.7,39.8,41.4,44.3,39.7,42.1,40.6,43.0,42.2,41.5,39.6,44.0,43.1,38.7,43.9])
new=np.array([48.5,49.1,50.2,47.8,48.7,49.9,48.0,50.5,49.8,49.6,48.2,48.9,49.7,50.3,49.4,50.1,48.6,48.3,49.0,50.0,48.4,49.3])

# %%
pop_std=2.5
n_sp=len(new)

# %%
mean_new=np.mean(new)
mean_old=np.mean(old)

# %%
z_cal2=(mean_new-mean_old)/(pop_std/np.sqrt(n_sp))
z_cal2
# Out:
# np.float64(13.57662161752527)

# %%
if (z_table)<(z_cal):
  print("Null hypothesis is rejected")
else:
  print("Null hypothesis is accepted")
# Out:
# Null hypothesis is rejected

# %% [markdown]
# #T Test

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import scipy.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import scipy.stats as st
import numpy as np

# %%
t_table= st.t.ppf(1-0,0.25,38)
t_table
# Out:
# np.float64(inf)

# %%
t_cal=(80-75)*(np.sqrt((25/20)+(26/20))) # Multiply the two expressions using the * operator
t_cal
# Out:
# np.float64(7.984359711335656)
